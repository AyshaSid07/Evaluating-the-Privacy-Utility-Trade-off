# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Trusted-AI/AIF360/blob/main/examples/sklearn/monthly_bee_datasets_metrics.ipynb)

# %% [markdown]
# # Method of the month (July) -- Dataset loading and running metrics

# %%
#Install AIF360
# !pip install 'aif360'
# Out:
# Requirement already satisfied: aif360 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (0.6.1)
# Requirement already satisfied: numpy>=1.16 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from aif360) (2.3.5)
# Requirement already satisfied: scipy>=1.2.0 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from aif360) (1.15.3)
# Requirement already satisfied: pandas>=0.24.0 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from aif360) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.0 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from aif360) (1.7.2)
# Requirement already satisfied: matplotlib in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from aif360) (3.10.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from pandas>=0.24.0->aif360) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from pandas>=0.24.0->aif360) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from pandas>=0.24.0->aif360) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->aif360) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from scikit-learn>=1.0->aif360) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from scikit-learn>=1.0->aif360) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from matplotlib->aif360) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from matplotlib->aif360) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from matplotlib->aif360) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from matplotlib->aif360) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from matplotlib->aif360) (25.0)
# Requirement already satisfied: pillow>=8 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from matplotlib->aif360) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages (from matplotlib->aif360) (3.2.5)

# %%
import pandas as pd
import seaborn as sns

from sklearn.compose import make_column_transformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler

from aif360.sklearn.datasets import fetch_adult, standardize_dataset
from aif360.sklearn.metrics import disparate_impact_ratio, average_odds_error
from aif360.sklearn.metrics import base_rate, ratio
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776080491.933986   26732 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776080491.987826   26732 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776080493.211911   26732 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages/inFairness/utils/ndcg.py:37: FutureWarning: We've integrated functorch into PyTorch. As the final step of the integration, `functorch.vmap` is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use `torch.vmap` instead; see the PyTorch 2.0 release notes and/or the `torch.func` migration guide for more details https://pytorch.org/docs/main/func.migrating.html
#   vect_normalized_discounted_cumulative_gain = vmap(
# /home/hampus/Documents/Skola/exjobb/thesis_env/lib/python3.12/site-packages/inFairness/utils/ndcg.py:48: FutureWarning: We've integrated functorch into PyTorch. As the final step of the integration, `functorch.vmap` is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use `torch.vmap` instead; see the PyTorch 2.0 release notes and/or the `torch.func` migration guide for more details https://pytorch.org/docs/main/func.migrating.html
#   monte_carlo_vect_ndcg = vmap(vect_normalized_discounted_cumulative_gain, in_dims=(0,))

# %% [markdown]
# ## Loading data

# %% [markdown]
# Datasets are formatted as separate `X` (# samples x # features) and `y` (# samples x # labels) DataFrames. The index of each DataFrame contains protected attribute values per sample. Datasets may also load a `sample_weight` object to be used with certain algorithms/metrics. All of this makes it so that aif360 is compatible with scikit-learn objects.
#
# For example, we can easily load the Adult dataset from UCI with the following line:

# %%
X, y, sample_weight = fetch_adult(binary_race=False)
X.head()
# Out:
#             age  workclass     education  education-num      marital-status  \
# race  sex
# Black Male   25    Private          11th              7       Never-married
# White Male   38    Private       HS-grad              9  Married-civ-spouse
#       Male   28  Local-gov    Assoc-acdm             12  Married-civ-spouse
# Black Male   44    Private  Some-college             10  Married-civ-spouse
# White Male   34    Private          10th              6       Never-married
#
#                    occupation   relationship   race   sex  capital-gain  \
# race  sex
# Black Male  Machine-op-inspct      Own-child  Black  Male             0
# White Male    Farming-fishing        Husband  White  Male             0
#       Male    Protective-serv        Husband  White  Male             0
# Black Male  Machine-op-inspct        Husband  Black  Male          7688
# White Male      Other-service  Not-in-family  White  Male             0
#
#             capital-loss  hours-per-week native-country
# race  sex
# Black Male             0              40  United-States
# White Male             0              50  United-States
#       Male             0              40  United-States
# Black Male             0              40  United-States
# White Male             0              30  United-States

# %% [markdown]
# The protected attribute information is also replicated in the labels (this will be useful when running metics):

# %%
y.head()
# Out:
# race   sex
# Black  Male    <=50K
# White  Male    <=50K
#        Male     >50K
# Black  Male     >50K
# White  Male    <=50K
# Name: annual-income, dtype: category
# Categories (2, object): ['<=50K' < '>50K']

# %% [markdown]
# By default, this will drop rows which include missing (NA) values. Changing the `dropna` arg will allow us to handle those samples differently, if we so choose.

# %%
X_num, y_num, _ = fetch_adult(dropna=False)
X.shape, X_num.shape
# Out:
# ((45222, 13), (48842, 13))

# %% [markdown]
# There are a number of other arguments one can explore. For example, the `numeric_only` arg will _drop_ all non-numeric columns (this will be useful for running `DisparateImpactRemover`). This is equivalent to using the `usecols` or `dropcols` arguments. Finally, these can all be done manually as well since the data are simply Pandas data types but it is convenient, especially when combined with `dropna` to use the provided interface.

# %% [markdown]
# We can then split the dataset

# %%
(X_train, X_test,
 y_train, y_test) = train_test_split(X, y, train_size=0.7, random_state=1234567)

# %% [markdown]
# and one-hot encode the categorical features:

# %%
import pandas as pd
from sklearn.base import BaseEstimator, MetaEstimatorMixin, clone


class PandasMeta(BaseEstimator, MetaEstimatorMixin):
    def __init__(self, estimator):
        self.estimator = estimator

    def fit(self, X, y=None, **fit_params):
        self.estimator_ = clone(self.estimator)
        self.estimator_.fit(X, y, **fit_params)
        return self

    def transform(self, X):
        assert isinstance(X, pd.DataFrame)
        output = self.estimator_.transform(X)
        if not isinstance(output, pd.DataFrame):
            output = pd.DataFrame(output, index=X.index)
            try:
                columns = self.estimator_.get_feature_names_out()
                output.columns = columns
            except:
                pass
        return output
    
    def fit_transform(self, X, y=None, **fit_params):
        assert isinstance(X, pd.DataFrame)
        self.estimator_ = clone(self.estimator)
        output = self.estimator_.fit_transform(X, y, **fit_params)
        if not isinstance(output, pd.DataFrame):
            output = pd.DataFrame(output, index=X.index)
            try:
                columns = self.estimator_.get_feature_names_out()
                output.columns = columns
            except:
                pass
        return output

# %%
pre = make_column_transformer(
        (OneHotEncoder(sparse=False), X_train.dtypes == 'category'),
        (StandardScaler(), X_train.dtypes != 'category'),
        verbose_feature_names_out=False)
pre = PandasMeta(pre)
pre.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 pre = make_column_transformer(
# ----> 2         (OneHotEncoder(sparse=False), X_train.dtypes == 'category'),
#       3         (StandardScaler(), X_train.dtypes != 'category'),
#       4         verbose_feature_names_out=False)
#       5 pre = PandasMeta(pre)
#       6 pre.fit_transform(X_train)
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %% [markdown]
# ## Running metrics

# %% [markdown]
# Now, we can get a baseline measurement for disparate impact ratio on the training data:

# %%
di_train = disparate_impact_ratio(y_train, prot_attr='sex', priv_group='Male', pos_label='>50K')
di_train
# Out:
# 0.36011001703880235

# %% [markdown]
# Sidenote: this is equivalent to:

# %%
ratio(base_rate, y_train, prot_attr='sex', priv_group='Male', pos_label='>50K')
# Out:
# 0.36011001703880235

# %% [markdown]
# With the data in this format, we can easily train a scikit-learn model and get predictions for the test data:

# %%
model = LogisticRegression(max_iter=1000)
grid = GridSearchCV(model, param_grid={'C': [1, 10]})
pipe = make_pipeline(pre, grid)

y_pred = pipe.fit(X_train, y_train).predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8461708557529299

# %% [markdown]
# ## Load a custom dataset
#
# We can just as easily load a dataset other than the ones included out-of-the-box. As an example, let us examine the ubiquitous Titanic dataset:

# %%
from sklearn.datasets import fetch_openml

X_ti, y_ti = fetch_openml("titanic", version=1, return_X_y=True)
X_ti.head()
# Out:
#    pclass                                             name     sex      age  \
# 0     1.0                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1     1.0                   Allison, Master. Hudson Trevor    male   0.9167
# 2     1.0                     Allison, Miss. Helen Loraine  female   2.0000
# 3     1.0             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4     1.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  boat   body  \
# 0    0.0    0.0   24160  211.3375       B5        S     2    NaN
# 1    1.0    2.0  113781  151.5500  C22 C26        S    11    NaN
# 2    1.0    2.0  113781  151.5500  C22 C26        S  None    NaN
# 3    1.0    2.0  113781  151.5500  C22 C26        S  None  135.0
# 4    1.0    2.0  113781  151.5500  C22 C26        S  None    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
y_ti = y_ti.astype(int)
y_ti.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: survived, dtype: int64

# %% [markdown]
# We use the `standardize_dataset` function to handle some of the preprocessing and protected attribute storage. We will only look at "age", "sex", "pclass" (passenger class), and "fare". We also drop samples with missing values.

# %%
X_ti, y_ti = standardize_dataset(X_ti, prot_attr='pclass', target=y_ti, usecols=['age', 'sex', 'pclass', 'fare'])
X_ti
# Out:
#             age     sex  pclass      fare
# pclass
# 1.0     29.0000  female     1.0  211.3375
# 1.0      0.9167    male     1.0  151.5500
# 1.0      2.0000  female     1.0  151.5500
# 1.0     30.0000    male     1.0  151.5500
# 1.0     25.0000  female     1.0  151.5500
# ...         ...     ...     ...       ...
# 3.0     45.5000    male     3.0    7.2250
# 3.0     14.5000  female     3.0   14.4542
# 3.0     26.5000    male     3.0    7.2250
# 3.0     27.0000    male     3.0    7.2250
# 3.0     29.0000    male     3.0    7.8750
#
# [1045 rows x 4 columns]

# %% [markdown]
# Class 1 passengers paid more for their tickets so we can assume they were of higher socio-economic status.

# %%
X_ti.groupby(X_ti.pclass).fare.mean()
# Out:
# pclass
# 1.0    92.229358
# 2.0    21.855044
# 3.0    12.879299
# Name: fare, dtype: float64

# %% [markdown]
# They also were about twice as likely to survive as non-first class passengers:

# %%
disparate_impact_ratio(y_ti, priv_group=1)
# Out:
# 0.5072128124523562
